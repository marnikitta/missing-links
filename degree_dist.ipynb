# %%
# %matplotlib  inline
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [16, 10]

# %%
with open('../1e7_degrees.data.bak') as f:
    data = np.array([np.int(x) for x in f.readline().strip().split(' ')])

# %%
plt.hist(np.log(data), log=True, bins=100)
# Out:
# (array([  1.42109900e+06,   1.26297800e+06,   1.00495600e+06,
#           8.90126000e+05,   7.14625000e+05,   6.86374000e+05,
#           5.45716000e+05,   5.08126000e+05,   4.02979000e+05,
#           3.67609000e+05,   2.94180000e+05,   2.65761000e+05,
#           2.34418000e+05,   1.95667000e+05,   1.64424000e+05,
#           1.48848000e+05,   1.23798000e+05,   1.09558000e+05,
#           9.05770000e+04,   7.93700000e+04,   6.93610000e+04,
#           5.93230000e+04,   4.94970000e+04,   4.36410000e+04,
#           3.69900000e+04,   3.24610000e+04,   2.75740000e+04,
#           2.40810000e+04,   2.03810000e+04,   1.77050000e+04,
#           1.50700000e+04,   1.28460000e+04,   1.14030000e+04,
#           9.45700000e+03,   8.34100000e+03,   7.09800000e+03,
#           6.07700000e+03,   5.24400000e+03,   4.41400000e+03,
#           3.95900000e+03,   3.33400000e+03,   2.92200000e+03,
#           2.48300000e+03,   2.09900000e+03,   1.78300000e+03,
# ...

# %%
plt.hist(data)
# Out:
# (array([  9.99972400e+06,   2.13000000e+02,   3.50000000e+01,
#           1.20000000e+01,   8.00000000e+00,   2.00000000e+00,
#           2.00000000e+00,   2.00000000e+00,   1.00000000e+00,
#           1.00000000e+00]),
#  array([  1.00000000e+02,   1.93577000e+04,   3.86154000e+04,
#           5.78731000e+04,   7.71308000e+04,   9.63885000e+04,
#           1.15646200e+05,   1.34903900e+05,   1.54161600e+05,
#           1.73419300e+05,   1.92677000e+05]),
#  <a list of 10 Patch objects>)
